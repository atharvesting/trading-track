# %%
# Initializing the resources needed

from src.screens.single_candle import SingleCandleAnalyser, Candle
sca = SingleCandleAnalyser(r"C:\Users\Atharv Rawat\Desktop\Main\IT\Projects\Trading Track\data\raw\reliance_data.csv")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Initializing the resources needed
# ----> 3 from src.screens.single_candle import SingleCandleAnalyser, Candle
#       4 sca = SingleCandleAnalyser(r"C:\Users\Atharv Rawat\Desktop\Main\IT\Projects\Trading Track\data\raw\reliance_data.csv")
#
# ModuleNotFoundError: No module named 'src'

# %%
test = (i for i in range(len(sca.data)))

cash = 100000

def buy(price:float, quantity:int):
    global cash
    total = price * quantity
    cash -= total
    return Order()

for i in test:
    if sca.is_bozo(i):
        buy(price=sca.data.loc[i].Close, quantity=1)
        break
    if sca.is_long(i):
        sell()
        break
